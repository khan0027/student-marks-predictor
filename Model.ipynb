# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

data = pd.read_csv("student_data.csv")

X = data[["Hours"]]
y = data["Score"]

model = LinearRegression()
model.fit(X, y)

hours = float(input("Enter number of hours studied: "))

# FIX: use DataFrame with column name
input_data = pd.DataFrame([[hours]], columns=["Hours"])

predicted_score = model.predict(input_data)

print(f"Predicted score for {hours} hours of study is: {predicted_score[0]:.2f}")
# Out:
# Enter number of hours studied:  6
# Predicted score for 6.0 hours of study is: 70.97
